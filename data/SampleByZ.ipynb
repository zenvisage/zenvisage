# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../../zenvisage/scatter/crime/
# Out:
# /Users/dorislee/Desktop/Research/zenvisage/scatter/crime

# %%
df = pd.read_csv("crimes.csv")

# %%
df.head()
# Out:
#         ID Case Number                    Date                  Block  IUCR  \
# 0  6111114    HP180720  02/17/2008 07:10:00 PM        043XX W 61ST ST  1811
# 1  6111119    HP202339  03/01/2008 02:00:00 AM  051XX S MASSASOIT AVE  1320
# 2  6111120    HP206624  03/03/2008 09:37:43 PM      049XX W CORTEZ ST  1310
# 3  6111121    HP205854  03/03/2008 11:44:05 AM        026XX E 92ND ST  2027
# 4  6111122    HP205015  03/02/2008 11:22:14 PM        010XX W 59TH ST  1811
#
#       Primary Type                   Description    Location Description  \
# 0        NARCOTICS  POSS: CANNABIS 30GMS OR LESS  VEHICLE NON-COMMERCIAL
# 1  CRIMINAL DAMAGE                    TO VEHICLE                  STREET
# 2  CRIMINAL DAMAGE                   TO PROPERTY               APARTMENT
# 3        NARCOTICS                   POSS: CRACK                SIDEWALK
# 4        NARCOTICS  POSS: CANNABIS 30GMS OR LESS                SIDEWALK
#
# ...

# %%
uniqueZ = df["IUCR"].unique()

# %%
len(uniqueZ)
# Out:
# 402

# %%
np.random.seed(999)
sampledZ = np.random.choice(uniqueZ, 200)

# %%
sampledZ
# Out:
# array(['5131', '5121', '3760', '0489', '0488', '0486', '0334', '1590',
#        '0450', '1140', '0330', '0915', '0820', '0820', '1235', '0918',
#        '2020', '1536', '3400', '2019', '5120', '1521', '4210', '0650',
#        '5120', '1330', '1360', '1661', '1090', '1812', '0487', '0545',
#        '2095', '1515', '1791', '0325', '0545', '033A', '0487', '1156',
#        '0291', '1170', '1620', '2050', '1330', '2016', '1335', '051B',
#        '1261', '5094', '0585', '0281', '2020', '2033', '2826', '0486',
#        '2230', '0481', '2028', '1035', '4387', '2030', '1130', '1365',
#        '1850', '2040', '1206', '1541', '0937', '5004', '1750', '0558',
#        '0430', '2060', '2826', '2830', '1624', '0479', '1725', '3740',
#        '3200', '4387', '2040', '0925', '4652', '3731', '0930', '0843',
#        '4240', '5073', '141A', '1670', '143A', '141A', '0553', '1265',
#        '2111', '1310', '0453', '3300', '1526', '1622', '1753', '2020',
# ...

# %%
df.head()
# Out:
#         ID Case Number                    Date                  Block  IUCR  \
# 0  6111114    HP180720  02/17/2008 07:10:00 PM        043XX W 61ST ST  1811
# 1  6111119    HP202339  03/01/2008 02:00:00 AM  051XX S MASSASOIT AVE  1320
# 2  6111120    HP206624  03/03/2008 09:37:43 PM      049XX W CORTEZ ST  1310
# 3  6111121    HP205854  03/03/2008 11:44:05 AM        026XX E 92ND ST  2027
# 4  6111122    HP205015  03/02/2008 11:22:14 PM        010XX W 59TH ST  1811
#
#       Primary Type                   Description    Location Description  \
# 0        NARCOTICS  POSS: CANNABIS 30GMS OR LESS  VEHICLE NON-COMMERCIAL
# 1  CRIMINAL DAMAGE                    TO VEHICLE                  STREET
# 2  CRIMINAL DAMAGE                   TO PROPERTY               APARTMENT
# 3        NARCOTICS                   POSS: CRACK                SIDEWALK
# 4        NARCOTICS  POSS: CANNABIS 30GMS OR LESS                SIDEWALK
#
# ...

# %%
sampled_df = df[df["IUCR"].isin(sampledZ)]

# %%
len(sampled_df)
# Out:
# 2406570

# %%
len(sampled_df["IUCR"].unique())
# Out:
# 156
